# %% [markdown]
# # Homework 6: A Systematic Homework on Randomness
#
# Physics 177, Spring 2017 (Prof. Tanedo)
# Revised: Monday, May 15th
# Due: Tuesday, May 23
#
# *Everardo Molina*

# %% [markdown]
# ## Problem 1: Drunkard's Walk in One Dimension
# This problem is motivated by Chapter 7 of *Computational Physics, Second Edition* by N. Giordano and H. Nakanishi.
#
#
# *Insert your favorite joke about the Thursday night wine and music events.*
#
# The drunkard's walk problem is an example of a **stochastic** system (randomness plays a key role). A drunkard walks randomly in one dimension, as defined by the following rule:
#
# * At each time step, the drunkard randomly picks a direction (forward or backward) and takes one step in that direction.
#
# In this problem, will use Python's `random` library to code the drunkard's walk in an array. You then relate this problem to diffusion in a physical system.

# %% [markdown]
# ### Problem 1a
#
# Code the drunkard's walk for `nSteps=1000` steps. Assume the drunkard starts at the original The result of your code should be an array of positions. It is also useful to keep an array of squared positions, $x^2$.
#
# Plot the drunkard's walk ($x$ as a function of step number) and the squared displacement ($x^2$ as a function of step number) for a given random seed.

# %%
from random import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin,cos
from numpy import pi as pi




number_steps = 1000
tpoints = np.arange(0, number_steps, 1)
start_location = 0

x = [0]

tpoints = np.arange(0, number_steps, 1)


for i in range (0,number_steps -1) :

    step = random()   
    if step >= .5:
        step = 1 
        
    elif step <.5:
        step = -1
    
    x.append(x[i] + step)
    
    
tt = np.array(tpoints)

xx = np.array(x)

plt.plot(tt,xx)
plt.xlabel('time')
plt.ylabel('x')
plt.title("random walk x")
plt.legend()
plt.show()



plt.plot(tt,xx**2)
plt.xlabel('time')
plt.ylabel('x^2')
plt.title("random walk x^2")
plt.show()
# Out:
# /Users/EMolina/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# # Problem 1b
# A more useful quantity is to examine the average of $x^2$ over many drunkards. For our purposes, pick nWalkers=100. Your code should output:
#
#
# $\langle x^2 \rangle = \frac{1}{n_\text{Walkers}} \sum_{i} x_i^2$
# where the sum over $i$ is a sum over the 100 walkers.
#
#
# The resulting plot should look much better behaved. In fact, it should fit to
#
#
# $\langle x^2 \rangle = 2 D t$,
#
#
# where $D$ is the diffusion constant. What is the value of $D$ based on your plot?

# %%
# %matplotlib 
number_steps = 1000
tpoints = np.arange(0, number_steps, 1)
start_location = 0
num_walkers = 100

x = [0]
     
walks = [0]*1000

n_walks = np.array(walks)


tpoints = np.arange(0, number_steps, 1)



for j in range (1,num_walkers):
  
     
    x=[0]

   
    for i in range (0,number_steps -1) :
       

        step = random()   
        if step >= .5:
            step = 1 
        
        elif step <.5:
            step = -1
    
        x.append(x[i] + step)
    
    
        tt = np.array(tpoints)

       
    xx = np.array(x)
       
    n_walks += xx**2
    
    
Avg_n_walks =   n_walks / num_walkers 
    

    
fig, ax = plt.subplots()
#Hi Corey
fit = np.polyfit(tt, Avg_n_walks, deg=1)
ax.plot(tt, fit[0] *  tt + fit[1], color='red')
plt.plot(tt,Avg_n_walks)
plt.xlabel('time')
plt.ylabel('x')
plt.title("random walk x")
plt.show()

# %% [markdown]
# ### Problem 1c
#
# Do the same thing for a drunkard's walk in three dimensions. Define the position of the particle to be a `numpy` array with three components. It may be helpful to define `numpy` arrays with the possible directions one can traverse.
#
# Store these directions in a list, `directions`.  A random step then corresponds to a shift by `sample(directions,1)[0]`. (Test this.)
#
# What is the value of $D$ for the 3D drunkard's walk?

# %%
# %matplotlib notebook
from random import *
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl



num_walkers = 100
number_steps = 1000
tpoints = np.arange(0, number_steps, 1)
start_location = 0

x = [0]
y = [0]
z = [0]






   
for i in range (0,number_steps-1) :
    step = randint(1, 6)
    if step == 1:
        step = 1
        x.append(x[i] + step)
        y.append(y[i])
        z.append(y[i])
    elif step == 2:
        step = -1
        x.append(x[i] + step)
        y.append(y[i])
        z.append(z[i])
    elif step == 3:
        step = 1
        x.append(x[i])
        y.append(y[i] + step)
        z.append(z[i])
    elif step == 4:
        step = -1
        x.append(x[i])
        y.append(y[i] + step)
        z.append(z[i])
    elif step == 5:
        step = 1
        x.append(x[i])
        y.append(y[i])
        z.append(z[i] + step)     
    elif step == 6:
        step = -1
        x.append(x[i])
        y.append(y[i])
        z.append(z[i] + step) 
   

tt = np.array(tpoints)
xx = np.array(x)
yy = np.array(y)
zz = np.array(z)
   
   


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(xx, yy, zz, label ='3d random walk')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from random import *
import matplotlib.pyplot as plt
import numpy as np
#from mpl_toolkits.mplot3d import Axes3D
#import matplotlib as mpl




number_steps = 1000
tpoints = np.arange(0, number_steps, 1)
start_location = 0

x = [0]
y = [0]
z = [0]


walks = [0]*1000
n_walks = np.array(walks)


for j in range (1,num_walkers):
     
    x=[0]
   
    for i in range (0,number_steps-1) :
        step = randint(1, 6)
        if step == 1:
            step = 1
            x.append(x[i] + step)
            y.append(y[i])
            z.append(y[i])
        elif step == 2:
            step = -1
            x.append(x[i] + step)
            y.append(y[i])
            z.append(z[i])
        elif step == 3:
            step = 1
            x.append(x[i])
            y.append(y[i] + step)
            z.append(z[i])
        elif step == 4:
            step = -1
            x.append(x[i])
            y.append(y[i] + step)
            z.append(z[i])
        elif step == 5:
            step = 1
            x.append(x[i])
            y.append(y[i])
            z.append(z[i] + step)     
        elif step == 6:
            step = -1
            x.append(x[i])
            y.append(y[i])
            z.append(z[i] + step) 
   
    xx = np.array(x)
       
    n_walks += xx**2

tt = np.array(tpoints)
#xx = np.array(x)
#yy = np.array(y)
#zz = np.array(z)
   
Avg_n_walks =   n_walks / num_walkers   

fig, ax = plt.subplots()
fit = np.polyfit(tt, Avg_n_walks, deg=1)
ax.plot(tt, fit[0] *  tt + fit[1], color='red')
plt.plot(tt,Avg_n_walks)
plt.xlabel('time')
plt.ylabel('x')
plt.title("random walk x")
plt.show()

# %% [markdown]
# ### Problem 1.x (extra credit)
#
# *This problem has no programming, I suggest working it out on paper and then sketching the proof here, with key steps written out explicitly*
#
# Derive the diffusion equation from the discretized drunkard's walk. For simplicity, work in two dimensions. Let $P(i,j,t)$ be the probability of finding the drunkard at site $(i,j)$ and time $t$. You want to show:
#
# $\displaystyle \frac{\partial P(x,y,t)}{\partial t} = D \nabla^2 P(x,y,t)$
#
# The key to this is the insight that the probability that the drunkard is at position $(i,j)$ at time $t$ is given by the equally weighted average of the probabilities that the drunkard was at one of the adjacent positions.
#
# Use this insight to re-write $P(i,j,t) - P(i,j,t-1)$ as a sum of terms that reproduces the Laplacian. You remember what the discretized Laplacian looks like, right?

# %% [markdown]
# ## Problem 2: Brownian Motion
#
# Let's use the 2D drunkard's walk to model Brownian motion.
#
# ### Problem 2a
#
# Imagine a 2D box of length `L=101`. Place a "drunkard" in the middle of the grid. The drunkard moves in one step in any direction (north, east, south, west) each step. If the drunk hits the wall, forbit motion that goes outside of the box.
#
# Animate the position of the drunkard as a funtion of time for some period of time.
#
# ### Problem 2b
#
# Same as problem 2a, but now populate the center of the box with 20 drunkards that each move randomly. For this problem, allow the drunkards to "stack" on top of each other if they overlap.
#
# ### Problem 2x (extra credit)
#
# Semi-self-avoiding drunkards. Same as problem 2b, but now prohibit any motion that would cause drunkards to overlap with each other. You'll have to come up with some appropriate initial condition where the drunkards all start close to each other in the center of the box. There may be conditions where a drunkard cannot move.

# %%
# %matplotlib notebook
import matplotlib.animation as animation

tpoints = np.arange(0, number_steps, 1)
number_steps = 1000
L = 101
x = [0]
y = [0]




for i in range (0,number_steps-1) :
    step = randint(1, 4)
    if step == 1:
        step = 1
        x.append(x[i] + step)
        y.append(y[i])
        
    elif step == 2:
        step = -1
        x.append(x[i] + step)
        y.append(y[i])
       
    elif step == 3:
        step = 1
        x.append(x[i])
        y.append(y[i] + step)
       
    elif step == 4:
        step = -1
        x.append(x[i])
        y.append(y[i] + step)
       
xx = np.array(x)
yy = np.array(y)

tt = np.array(tpoints)


fig,ax = plt.figure()
ax = fig.add_subplot(111, autoscale_on=False, xlim=(-50.5, 50.5), ylim=(-50.5, 50.5))
ax.grid()

def init():
    line.set_data([], [])
    return (line,)

def animate(i):
    x = xx[i]
    y = yy[i]
    line.set(x,y)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
plt.show()
# Out:
# <div id='9bb531a5-8317-42a1-a196-7074fdfbf7a0'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-51f52ea48b20> in <module>()
#      39
#      40
# ---> 41 fig,ax = plt.figure()
#      42 ax = fig.add_subplot(111, autoscale_on=False, xlim=(-50.5, 50.5), ylim=(-50.5, 50.5))
#      43 ax.grid()
#
# TypeError: 'Figure' object is not iterable

# %% [markdown]
# ## Problem 3: Hyperspheres and Monte Carlo
#
# Calculate the volume of a unit $n$-sphere for the cases $n$ = 2,3,4,5,6. Use the **Monte Carlo** "throwing marbles" method where you randomly sample points in an $n$-dimensional unit cube and keep track of how many points fall within the condition
#
# $\sum_i^n x_i^2 < 1$.
#
# Compare to the analytic formulae here: https://en.wikipedia.org/wiki/Volume_of_an_n-ball
#
# ### Problem 3x
#
# Plot the estimated hypervolume as a function of number of random samples used, and plot (as a horizontal line) the correct values from the analytic formula. Alternatively, plot the "difference from the true result" as a function of number of samples.
#
# Comment on how the number of samples required depends on the dimensionality of the hypersphere.

# %%
# %matplotlib inline



def Pi_Estimate_2(nsample):
    count = 0
    for i in range(nsample):
        x = random()
        y = random()
    
        
       
       
        if x**2 + y**2  < 1:
            count += 1
    return (2**2)*count/nsample

N = 100000

for i in range (10):
    print(Pi_Estimate_2(N))
# Out:
# 3.13688
# 3.14596
# 3.13312
# 3.13288
# 3.13576
# 3.13464
# 3.14648
# 3.14364
# 3.13512
# 3.15396

# %%
plt.plot(,nsample)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-1bc13b0daeeb> in <module>()
# ----> 1 plt.plot((2**2)*count/nsample,nsample)
#       2 plt.show()
#
# NameError: name 'count' is not defined

# %%
#nsample =  3

def Pi_Estimate_3(nsample):
    count = 0
    for i in range(nsample):
        x = random()
        y = random()
        z = random()
        
       
       
        if x**2 + y**2 + z**2 < 1:
            count += 1
    return (2**3)*count/nsample

N = 100000

for i in range (10):
    print(Pi_Estimate_3(N))
# Out:
# 4.18896
# 4.1892
# 4.19248
# 4.19976
# 4.18672
# 4.18792
# 4.14704
# 4.1792
# 4.18584
# 4.182

# %%
plt.plot(Pi_Estimate_3(nsample),nsample)
plt.show()

# %%
nsample =  4

def Pi_Estimate_4(nsample):
    count = 0
    for i in range(nsample):
        x = random()
        y = random()
        z = random()
        a = random()
       
       
        if x**2 + y**2 + z**2 + a**2< 1:
            count += 1
    return (2**4)*count/nsample

N = 100000

for i in range (10):
    print(Pi_Estimate_3(N))
# Out:
# 4.2008
# 4.16736
# 4.18344
# 4.2144
# 4.17536
# 4.19312
# 4.186
# 4.19024
# 4.17976
# 4.2028

# %%
#nsample =  5

def Pi_Estimate_5(nsample):
    count = 0
    for i in range(nsample):
        x = random()
        y = random()
        z = random()
        a = random()
        b = random()
       
       
        if x**2 + y**2 + z**2 + a**2 + b**2< 1:
            count += 1
    return (2**5)*count/nsample

N = 100000

for i in range (10):
    print(Pi_Estimate_5(N))
# Out:
# 5.24256
# 5.28224
# 5.2976
# 5.256
# 5.1776
# 5.28896
# 5.23776
# 5.25888
# 5.30432
# 5.30752

# %%
#nsample =  6

def Pi_Estimate_6(nsample):
    count = 0
    for i in range(nsample):
        x = random()
        y = random()
        z = random()
        a = random()
        b = random()
        c = random()
       
       
        if x**2 + y**2 + z**2 + a**2 + b**2 + c**2 < 1:
            count += 1
    return (2**6)*count/nsample

N = 100000

for i in range (10):
    print(Pi_Estimate_6(N))
# Out:
# 5.16416
# 5.14496
# 5.20512
# 5.16032
# 5.12896
# 5.15008
# 5.13728
# 5.13792
# 5.20896
# 5.06048
